# %%
data = """cp-atrium-mobilenets-0.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-0 cp: 0.3263289414
cp-atrium-mobilenets-3.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-3 cp: 0.33115917153
cp-atrium-mobilenets-9.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-9 cp: 0.326033779849
cp-atrium-mobilenets-15.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-15 cp: 0.3278535619
cp-atrium-mobilenets-21.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-21 cp: 0.3291719162
cp-atrium-mobilenets-27.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-27 cp: 0.3263944796
cp-atrium-mobilenets-33.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-33 cp: 0.320571428571
cp-atrium-mobilenets-39.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-39 cp: 0.311762684687
cp-atrium-mobilenets-45.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-45 cp: 0.296871431834
cp-atrium-mobilenets-51.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-51 cp: 0.286185657721
cp-atrium-mobilenets-57.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-57 cp: 0.277610980056
cp-atrium-mobilenets-63.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-63 cp: 0.275751417264
cp-atrium-mobilenets-69.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-69 cp: 0.270451959872
cp-atrium-mobilenets-75.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-75 cp: 0.251417769376
cp-atrium-mobilenets-81.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-81 cp: 0.238480264302
cp-atrium-mobilenets-84.txt:../models/atc/pedestrian/atrium/atrium-mobilenets-84 cp: 0.219361147327"""
data = [x.split(" cp: ") for x in data.split("\n")]
data = [(x.split("/")[-1], float(y)) for x, y in data]

# %%
dict(data)
# Out:
# {'atrium-mobilenets-0': 0.3263289414,
#  'atrium-mobilenets-15': 0.3278535619,
#  'atrium-mobilenets-21': 0.3291719162,
#  'atrium-mobilenets-27': 0.3263944796,
#  'atrium-mobilenets-3': 0.33115917153,
#  'atrium-mobilenets-33': 0.320571428571,
#  'atrium-mobilenets-39': 0.311762684687,
#  'atrium-mobilenets-45': 0.296871431834,
#  'atrium-mobilenets-51': 0.286185657721,
#  'atrium-mobilenets-57': 0.277610980056,
#  'atrium-mobilenets-63': 0.275751417264,
#  'atrium-mobilenets-69': 0.270451959872,
#  'atrium-mobilenets-75': 0.251417769376,
#  'atrium-mobilenets-81': 0.238480264302,
#  'atrium-mobilenets-84': 0.219361147327,
#  'atrium-mobilenets-9': 0.326033779849}

# %%
import matplotlib
from matplotlib import rcParams
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("talk", font_scale=1.6)
a = {int(x.split("-")[-1]): y for x, y in data}
import pandas as pd
# %matplotlib inline
aa = sorted(a.items())
xx, yy = zip(*aa)
plt.plot(xx, yy, '-*')
plt.xlabel('# of layers frozen')
plt.ylabel('Conditional probability')
plt.ylim(0, .4)
plt.xlim(0, 90)
plt.title("atrium-mobilenets")
plt.tight_layout()
plt.savefig("cond_prob-atrium-mobilenets.pdf")
